# %%
import gzip
from tqdm import tqdm
import json
import pandas as pd
import numpy as np
import networkx as nx
from networkx.algorithms import bipartite
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import datetime

# %%
with open('all_data.json' , 'r') as f:
    data = list(map(json.loads, f))
with open('all_data2.json' , 'r') as f:
    data2 = list(map(json.loads, f))

# %% [markdown]
# ### convert into dataframe

# %%
def to_df(data):
    rating = []
    verified = []
    user = []
    asin = []
    review = []
    summary = []
    time = []
    category = []
    for i in data:

        rating.append(i['overall'])
        verified.append(i['verified'])
        user.append(i['reviewerID'])
        asin.append(i['asin'])
        if 'reviewText' not in i:
            review.append(np.nan)
        else:
            review.append(i['reviewText'])
        if 'summary' not in i:
            summary.append(np.nan)
        else:
            summary.append(i['summary'])
        time.append(i['unixReviewTime'])
        category.append(i['category'][:-2])
    df = pd.DataFrame({
                    'rating':rating, 
                    'verified': verified, 
                    'user': user,
                    'asin':asin,
                    'review':review,
                    'summary': summary,
                    'time':time,
                    'category': category
    })
    return df
df = to_df(data)
df2 = to_df(data2)

# %%
df
# Out:
#         rating  verified            user        asin  \
# 0          5.0      True  A2HOI48JK8838M  B00004U9V2
# 1          5.0      True   AXBTO9HB020I7  B00014351Q
# 2          1.0      True   AUAI9MEBEBLL7  B00014340I
# 3          5.0      True  A1SFKLLC60TL69  B000142FVW
# 4          5.0     False   A96JD9312DHWC  B00014GT8W
# ...        ...       ...             ...         ...
# 340834     5.0      True  A22DOC6FT7ZHBZ  B01GKU5UJY
# 340835     5.0     False   AOGBL9Z3ZCKLC  B01GUFFQDE
# 340836     5.0      True  A2A13IGJ2U5QDO  B01H3GZ07G
# 340837     1.0     False  A2PPSQHFAIRPV4  B01HB7JWKI
# 340838     3.0      True  A32N9N3HHLAY5R  B01HJBWFBO
#
#                                                    review  \
# 0       This handcream has a beautiful fragrance. It d...
# 1                                Very nice summer polish!
# 2       This is almost white. Not nearly the pink they...
# 3                                          Love the color
# 4       I absolutely LOVE Dermablend makeup line. They...
# ...                                                   ...
# 340834  If you use rotary cutters like I no these are ...
# 340835  Perfect set for card making. Very versatile fo...
# 340836                                               NICE
# 340837  Very upsetting, disappointing and embarrassing...
# 340838  Core is very hard and does not transfer color ...
#
#                                                   summary        time  \
# 0                                     Beautiful Fragrance  1515110400
# 1                                              Five Stars  1472428800
# 2                                           Took a chance  1519344000
# 3                                              Five Stars  1467676800
# 4                             A cover creme like no other  1501632000
# ...                                                   ...         ...
# 340834                                    Rulers grippers  1488412800
# 340835                                  Wonderful Variety  1536537600
# 340836                                         Five Stars  1512086400
# 340837                              Very disappointing!!!  1508371200
# 340838  Color on paper is not very saturated due to ha...  1515283200
#
#                       category
# 0                Luxury_Beauty
# 1                Luxury_Beauty
# 2                Luxury_Beauty
# 3                Luxury_Beauty
# 4                Luxury_Beauty
# ...                        ...
# 340834  Arts_Crafts_and_Sewing
# 340835  Arts_Crafts_and_Sewing
# 340836  Arts_Crafts_and_Sewing
# 340837  Arts_Crafts_and_Sewing
# 340838  Arts_Crafts_and_Sewing
#
# [340839 rows x 8 columns]

# %%
df[df['review'].isnull() | df['summary'].isnull()]
# Out:
#         rating  verified            user        asin  \
# 5944       3.0      True  A2BW265LP9RFVJ  B011R5FWN6
# 6850       5.0      True  A3SSGJMTJC7G6T  B001H9NV9A
# 8388       5.0      True  A2850SM9H6QERK  B001SICHU4
# 8786       4.0      True  A2BY9TQ7LRUSBX  B0053BSNZU
# 9061       5.0      True  A1BITOCNA3XPXL  B00BBF2TO8
# ...        ...       ...             ...         ...
# 335509     5.0      True  A2NKJJMSCWC8SG  B00BNVAYCE
# 335559     4.0     False   AAI1X9U5ASXY2  B00CY8BIZM
# 336558     5.0      True   A84ST4WZR91VW  B000BY4Q5K
# 340267     5.0      True  A35JHP6O4H0WGU  B003A7O2O0
# 340651     5.0      True   A8BL0LMEP6GR7  B00L6RKMGS
#
#                                                    review  \
# 5944                                                  NaN
# 6850                                                  NaN
# 8388                                                  NaN
# 8786    Game is in good shape. Haven't had any problem...
# 9061                   great to use for different players
# ...                                                   ...
# 335509                                                NaN
# 335559                                                NaN
# 336558                                                NaN
# 340267                                     Great product.
# 340651                                   Beautiful colors
#
#                                                   summary        time  \
# 5944                                          Three Stars  1506211200
# 6850                                           Five Stars  1496707200
# 8388                                           Five Stars  1462838400
# 8786                                                  NaN  1476835200
# 9061                                                  NaN  1486252800
# ...                                                   ...         ...
# 335509  EZ to install. Use a 3/32" pilot drill. Check ...  1517616000
# 335559                                         nice knife  1520812800
# 336558                                         Five Stars  1463097600
# 340267                                                NaN  1478995200
# 340651                                                NaN  1531353600
#
#                           category
# 5944         Patio_Lawn_and_Garden
# 6850         Patio_Lawn_and_Garden
# 8388                   Video_Games
# 8786                   Video_Games
# 9061                   Video_Games
# ...                            ...
# 335509  Tools_and_Home_Improvement
# 335559  Tools_and_Home_Improvement
# 336558      Arts_Crafts_and_Sewing
# 340267      Arts_Crafts_and_Sewing
# 340651      Arts_Crafts_and_Sewing
#
# [345 rows x 8 columns]

# %%
df.sort_values(by = 'time')
# Out:
#         rating  verified            user        asin  \
# 176540     5.0      True  A1XYEOL5UI0A0V  B0181RA0OE
# 39377      5.0      True  A11ZVACM386LJY  B00A03KMC8
# 36483      2.0      True  A3DROSWQQ3WGQG  B007UNSGB0
# 147181     5.0      True   ANW0OTOGX9Q5B  B00R36755M
# 137000     5.0      True  A3FJKWSI9KAGOB  B00E2563AU
# ...        ...       ...             ...         ...
# 168575     5.0      True   AIY6PIG4JN3JZ  B01HHHX64K
# 107998     3.0      True  A2HYXZO6AJYZ6W  B01H7HJEFK
# 168538     4.0      True  A1EBJGG8INODP3  B01H3S99M6
# 107957     4.0      True  A1YI0K51WRRZ9H  B01H2L50JA
# 168569     5.0      True  A1RBAOAPB8GDJJ  B01HFF4X7I
#
#                                                    review  \
# 176540  Great fit feels very natural to the grip.  No ...
# 39377                 these are great. Stretchy and warm.
# 36483   I liked this suitcase initially. When I packed...
# 147181  Okay, I know it seems silly to buy a coozie fo...
# 137000                                         Very nice!
# ...                                                   ...
# 168575                                     Really strong!
# 107998                                   ok for the price
# 168538  As expected, works great, various sizes is a b...
# 107957  I wore these shoes for an 8+ hour day of cross...
# 168569  This 1/4" pad measures almost a full 1/2" out ...
#
#                                           summary        time  \
# 176540                                Great Cover  1451692800
# 39377                                  Five Stars  1451692800
# 36483                             Mine was a dud!  1451692800
# 147181                     It really is worth it!  1451692800
# 137000                                 Five Stars  1451692800
# ...                                           ...         ...
# 168575                                 Five Stars  1538352000
# 107998                            just ok product  1538438400
# 168538                                Works great  1538438400
# 107957  Very comfortable for 8+ hours of training  1538438400
# 168569                                      Plush  1538524800
#
#                            category
# 176540  Cell_Phones_and_Accessories
# 39377    Clothing_Shoes_and_Jewelry
# 36483    Clothing_Shoes_and_Jewelry
# 147181             Home_and_Kitchen
# 137000             Home_and_Kitchen
# ...                             ...
# 168575             Home_and_Kitchen
# 107998   Clothing_Shoes_and_Jewelry
# 168538             Home_and_Kitchen
# 107957   Clothing_Shoes_and_Jewelry
# 168569             Home_and_Kitchen
#
# [340839 rows x 8 columns]

# %%
item_in_cat = df.groupby('category')['asin'].agg(set)
item_in_cat[:4]
# Out:
# category
# AMAZON_FASHION            {B009MA34NY, B014IBJKNO, B005AGO4LU, B001IKJOL...
# All_Beauty                {B00006L9LC, B000FI4S1E, B0009RF9DW, B0012Y0ZG...
# Appliances                             {B0014CN8Y8, B0006GVNOA, B00MGMWTQS}
# Arts_Crafts_and_Sewing    {B006P88WRE, B01CRNL4R0, B00RF4968Q, B001C1Y5F...
# Name: asin, dtype: object

# %%
len(item_in_cat)
# Out:
# 25

# %%
item_in_cat
# Out:
# category
# AMAZON_FASHION                 {B009MA34NY, B014IBJKNO, B005AGO4LU, B001IKJOL...
# All_Beauty                     {B00006L9LC, B000FI4S1E, B0009RF9DW, B0012Y0ZG...
# Appliances                                  {B0014CN8Y8, B0006GVNOA, B00MGMWTQS}
# Arts_Crafts_and_Sewing         {B006P88WRE, B01CRNL4R0, B00RF4968Q, B001C1Y5F...
# Automotive                     {B00B7MRCM4, B019FIERRO, B005I5GLCS, B009BFBL9...
# Cell_Phones_and_Accessories    {B006GCE5QQ, B00RNDRXIY, B00ING8KB4, B00JTDNCY...
# Clothing_Shoes_and_Jewelry     {B01416ZH4M, B00LIM6W2Y, B0025ZPQXE, B00DJBCQX...
# Digital_Music                  {B00122OUI8, B001GEOGIG, B003TKOJO6, B00L1SKW8...
# Electronics                    {B000RL9RP6, B001OC5JKY, B003XINM2E, B00BWS34R...
# Gift_Cards                     {B00MV9GCYQ, B01E4QUN0W, B00CXZPG0O, B005DHN6E...
# Grocery_and_Gourmet_Food       {B00CLPUYTO, B00AX0CYWE, B006N0U0K6, B003ZUJ35...
# Home_and_Kitchen               {B00440EKRG, B00TX79C1O, B0083UX3A8, B00L96BWT...
# Industrial_and_Scientific      {B004I2GPI2, B000IJYRDE, B00INL0BTS, B000H9FXE...
# Luxury_Beauty                  {B00M0V39VE, B002RS6JSA, B00LA5NHXQ, B01BQMKPN...
# Magazine_Subscriptions         {B00007B10Y, B00005N7SC, B000FTJ7JQ, B000LXHJF...
# Musical_Instruments            {B013RX1IJI, B0007Y09VO, B000RYPN38, B001PGXHX...
# Office_Products                {B000AN5AWK, B01GZGW5CS, B001TQ7T58, B00F63LP6...
# Patio_Lawn_and_Garden          {B00E9PUKJS, B000LNX06C, B001RV515K, B000ARPJP...
# Pet_Supplies                   {B007CRC9X0, B00C7645ME, B010T2AG84, B0002APQ5...
# Prime_Pantry                   {B00N0WZYS8, B000RAB8IG, B00I3MVY9I, B00X7ZXHS...
# Software                       {B001GL6QHS, B004E564PW, B008XAXAC4, B00N9MUV9...
# Sports_and_Outdoors            {B0039ZJSHY, B004HVZG7K, B011PM9EG2, B000276CZ...
# Tools_and_Home_Improvement     {B005TLVN9C, B00166SYD2, B00KXQFM2M, B01ASX06X...
# Toys_and_Games                 {B01FAPXJ4I, B00COMZLE2, B015XM5IUQ, B0160JCGG...
# Video_Games                    {B009AOFNU4, B000ARJ1RQ, B000KUHR8S, B00773690...
# Name: asin, dtype: object

# %% [markdown]
# ### Check if item belong to multiple category

# %%
item_cat = df.groupby('asin')['category'].agg(set)
item_cat[:4]
# Out:
# asin
# 0101635370        {Electronics}
# 0140503528    {Office_Products}
# 0209688726         {Automotive}
# 0310802636    {Office_Products}
# Name: category, dtype: object

# %%
sum(item_cat.apply(lambda x: len(x)) > 1)
# Out:
# 0

# %%
item_cat = item_cat.apply(lambda x:x.pop())
item_cat
# Out:
# asin
# 0101635370                   Electronics
# 0140503528               Office_Products
# 0209688726                    Automotive
# 0310802636               Office_Products
# 0439499887               Office_Products
#                          ...
# B01HJD4BBE    Clothing_Shoes_and_Jewelry
# B01HJDGJ1E           Sports_and_Outdoors
# B01HJF90LS    Tools_and_Home_Improvement
# B01HJFFHTC                   Electronics
# B01HJI17Y8                    Automotive
# Name: category, Length: 251573, dtype: object

# %%
df.sort_values(by = 'time').iloc[-1]['time']
# Out:
# 1538524800

# %%
class Simulation:
    def __init__(self, df, di = False):
        
        self.model = nx.DiGraph() if di else nx.Graph()
        self.df = df.sort_values(by = 'time')
        self.item_cat = df.groupby('asin')['category'].max()
    
    #min t: 1451692800 max t: 1538524800
    def add_node(self, t_start: int, t_end: int):
        df_part = self.df[(self.df['time'] >= t_start) & (self.df['time'] <= t_end)]
        '''
        user_added = set(df_part['user'])
        self.model.add_nodes_from([(node, {'category':'user'}) for node in user_added], bipartite=0)
        
        item_added = set(df_part[['asin', 'category']].itertuples(index=False, name=None))
        self.model.add_nodes_from([(node, {'category':category}) for (node, category) in item_added], bipartite=1)
        '''
        df_part['line_attr'] = df_part.apply(lambda x: {'time': x['time'], 'rating':x['rating']}, axis = 1)
        self.model.add_edges_from(df_part[['user','asin','line_attr']].itertuples(index=False, name=None))
        for i in self.model:
            if i in self.item_cat:
                self.model.nodes[i]['category'] = self.item_cat[i]
                self.model.nodes[i]['bipartite'] = 1
            else:
                self.model.nodes[i]['category'] = 'user'
                self.model.nodes[i]['bipartite'] = 0
            
    def get_sets(self) -> tuple:
        top_nodes = {n for n, d in self.model.nodes(data=True) if d["bipartite"] == 0}
        #bottom_nodes = set(self.model) - top_nodes
        return bipartite.sets(self.model, top_nodes)
    
    def get_color_pos(self):
        color_map = []
        pos = {}
        height = 0

        for i in self.model:
            cat = s.model.nodes[i]['category']
            
            if cat == 'user':
                last = i
            else:
                if i in s.model[last]:
                    height = (s.model[last][i]['time'] - 1451692800) / (5*864000)
                
            if  cat == 'user':
                color_map.append('xkcd:blue')
                pos[i] = (np.random.uniform(0,1), height)
            elif cat == 'AMAZON_FASHION':
                color_map.append('xkcd:red')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'All_Beauty':
                color_map.append('xkcd:coral')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Appliances':
                color_map.append('xkcd:crimson')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Arts_Crafts_and_Sewing':
                color_map.append('xkcd:cyan')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Automotive':
                color_map.append('xkcd:beige')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Cell_Phones_and_Accessories':
                color_map.append('xkcd:brown')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Clothing_Shoes_and_Jewelry':
                color_map.append('xkcd:chartreuse')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Digital_Music':
                color_map.append('xkcd:chocolate')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Electronics':
                color_map.append('xkcd:darkgreen')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Gift_Cards':
                color_map.append('xkcd:fuchsia')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Grocery_and_Gourmet_Food':
                color_map.append('xkcd:gold')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Home_and_Kitchen':
                color_map.append('xkcd:green')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Industrial_and_Scientific':
                color_map.append('xkcd:grey')
                pos[i] = (np.random.uniform(4,5), height) 
            elif cat == 'Luxury_Beauty':
                color_map.append('xkcd:khaki')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Magazine_Subscriptions':
                color_map.append('xkcd:lavender')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Musical_Instruments':
                color_map.append('xkcd:lime')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Office_Products':
                color_map.append('xkcd:olive')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Patio_Lawn_and_Garden':
                color_map.append('xkcd:orange')
                pos[i] = (np.random.uniform(4,5), height)
                
            elif cat == 'Pet_Supplies':
                color_map.append('xkcd:orchid')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Prime_Pantry':
                color_map.append('xkcd:purple')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Software':
                color_map.append('xkcd:teal')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Sports_and_Outdoors':
                color_map.append('xkcd:wheat')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Tools_and_Home_Improvement':
                color_map.append('xkcd:yellow')
                pos[i] = (np.random.uniform(4,5), height)
            elif cat == 'Toys_and_Games':
                color_map.append('xkcd:aquamarine')
                pos[i] = (np.random.uniform(4,5), height)
                
            elif cat == 'Video_Games':
                color_map.append('xkcd:goldenrod')
                pos[i] = (np.random.uniform(4,5), height)
            else:
                raise Exception("class missing")
            
        return color_map, pos

    def draw(self, fig_size = (12,30), node_size = 2, width = 0.09, save = False):
        plt.figure(figsize = fig_size)
        color_map, pos = self.get_color_pos()
        nx.draw(self.model, node_size = node_size, pos = pos, width = width, node_color=color_map)
        if save:
            latest = self.df.iloc[-1]['time'] 
            
            dt = datetime.date.fromtimestamp(latest)
            plt.title("Until: {}".format(dt))
            plt.savefig('./plots/Amazon{}.png'.format(dt), bbox_inches='tight')
        '''nx.draw_networkx(
        self.model,
        pos = nx.drawing.layout.bipartite_layout(self.model, self.get_sets()[0]),
        node_size = 3,
        with_labels=False,
        width = 0.03)''' # Or whatever other display options you like
        
    def get_projection(self, s: int) -> nx.classes.graph.Graph:
        bi_sets = self.get_sets()
        return bipartite.projected_graph(self.model, bi_sets[s])

# %%
s = Simulation(df[['rating','user','asin','time','category']][:10000])
s.model.nodes()
# Out:
# NodeView(())

# %%
s.add_node(0, 1508524800)
s.model.edges()
# Out:
#       rating            user        asin        time               category
# 8715     5.0  A14DU1XG5WW3YN  B0050SWP96  1451692800            Video_Games
# 5090     5.0   AJH7L7I3CL53U  B00KMRHQNA  1451692800  Patio_Lawn_and_Garden
# 8713     5.0  A39IZFSBWWP9H4  B0050SVNZ8  1451692800            Video_Games
# 2903     3.0   AXOEP68E1WRBR  B003YL4MG0  1451692800  Patio_Lawn_and_Garden
# 8227     5.0  A1CPCXK1C9R6JM  B0012R58LG  1451692800            Video_Games
# ...      ...             ...         ...         ...                    ...
# 4883     5.0  A1RVOT4ZHPEEHS  B00ICFV0LS  1508371200  Patio_Lawn_and_Garden
# 8908     5.0   AUZVIRAWZYKXN  B006ZTHGCK  1508457600            Video_Games
# 8720     5.0  A2R03U5UAX219B  B0050SWTAQ  1508457600            Video_Games
# 4582     5.0  A277TW85S5GLG2  B00F8C0XLG  1508457600  Patio_Lawn_and_Garden
# 6105     5.0   AFD42SPKLWR2V  B015UU4PB4  1508457600  Patio_Lawn_and_Garden
#
# [7966 rows x 5 columns]
# [('A14DU1XG5WW3YN', 'B0050SWP96', {'time': 1451692800, 'rating': 5.0}), ('AJH7L7I3CL53U', 'B00KMRHQNA', {'time': 1451692800, 'rating': 5.0}), ('A39IZFSBWWP9H4', 'B0050SVNZ8', {'time': 1451692800, 'rating': 5.0}), ('AXOEP68E1WRBR', 'B003YL4MG0', {'time': 1451692800, 'rating': 3.0}), ('A1CPCXK1C9R6JM', 'B0012R58LG', {'time': 1451692800, 'rating': 5.0}), ('A167P2DHO7P5D7', 'B00R9NWEFK', {'time': 1451692800, 'rating': 3.0}), ('A396VHMYQHW5KE', 'B00RNDC6JU', {'time': 1451692800, 'rating': 5.0}), ('A3UTOJF5NHJI0Q', 'B00005O0I8', {'time': 1451692800, 'rating': 5.0}), ('A1CPCXK1C9R6JM', 'B0012R58LG', {'time': 1451692800, 'rating': 5.0}), ('A3B8SXBDWL1UFC', 'B00QLWZWMW', {'time': 1451692800, 'rating': 3.0}), ('A2PL7PSCA87CXN', 'B00FVVVSUY', {'time': 1451692800, 'rating': 3.0}), ('AAGT3SY5BDGOG', 'B001ELW98K', {'time': 1451692800, 'rating': 5.0}), ('A2C2F7L10X1QCI', 'B000R37S00', {'time': 1451779200, 'rating': 5.0}), ('A1ZSAWV7G5RSFW', 'B000HEB3UU', {'time': 1451779200, 'rating': 4.0}), ('A23N9PENVBQ6HC', 'B00CTOGJIW', {'time': 1451779200, 'rating': 5.0}), ('A20IBN6OIYFJQD', 'B007WQFKNC', {'time': 1451779200, 'rating': 5.0}), ('A1B7ZUQCAQB011', 'B00DNGQQUQ', {'time': 1451779200, 'rating': 5.0}), ('A2K2SRY22AEMGX', 'B001PKU5MW', {'time': 1451779200, 'rating': 5.0}), ('A3AP5XRC59REFB', 'B001B1OI0A', {'time': 1451779200, 'rating': 3.0}), ('A1XPYI1RPDQLNZ', 'B0097TM6AC', {'time': 1451779200, 'rating': 5.0}), ('A2JEFXZATFYV3K', 'B006ZUNKL0', {'time': 1451779200, 'rating': 5.0}), ('A2Y1INHBJOQY0D', 'B00AAS888S', {'time': 1451779200, 'rating': 5.0}), ('A1H1U67JFF7N7T', 'B0098R0600', {'time': 1451865600, 'rating': 5.0}), ('A3MMM8X8W07O19', 'B000FFA08C', {'time': 1451865600, 'rating': 5.0}), ('AZF6PHVCUN8GI', 'B00550EIDA', {'time': 1451865600, 'rating': 5.0}), ('AFBCOD46GIFQ7', 'B000WZL5GQ', {'time': 1451865600, 'rating': 5.0}), ('AFBCOD46GIFQ7', 'B000WZL5GQ', {'time': 1451865600, 'rating': 5.0}), ('A30EBZKII2V5VX', 'B00W76UJBK', {'time': 1451865600, 'rating': 5.0}), ('ABRJBPP4ZBMW1', 'B016BBM6FI', {'time': 1451865600, 'rating': 5.0}), ('A11PK2MO25K5QW', 'B00201EFK8', {'time': 1451865600, 'rating': 5.0}), ('A1NHAL9A6RWQ62', 'B00005NOFH', {'time': 1451865600, 'rating': 5.0}), ('A7HKGNXQD7LVP', 'B00M0Z04C2', {'time': 1451865600, 'rating': 1.0}), ('A11G2YC3X2KFJB', 'B00CBNVAE4', {'time': 1451865600, 'rating': 4.0}), ('A2O822D7AOKDOG', 'B00HEAS7JA', {'time': 1451865600, 'rating': 5.0}), ('A2E2TIXKHWDKZZ', 'B00DHOBFDW', {'time': 1451865600, 'rating': 5.0}), ('A3TVY6OQF9R11A', 'B00DEE7F7K', {'time': 1451952000, 'rating': 5.0}), ('A3UG1SIKT89BO6', 'B0079GHJXY', {'time': 1451952000, 'rating': 4.0}), ('A2AD38PUZ3C4HD', 'B002E41PVS', {'time': 1451952000, 'rating': 5.0}), ('A3G4346778UN92', 'B00FLLFJOU', {'time': 1451952000, 'rating': 5.0}), ('A27I9VC2SP5VDN', 'B00MUY0OFU', {'time': 1451952000, 'rating': 5.0}), ('A1B6ZHDSQZBEQX', 'B007XUQXL0', {'time': 1451952000, 'rating': 3.0}), ('A3TX4F65UWRO5X', 'B000HCLLNG', {'time': 1451952000, 'rating': 5.0}), ('A20ROZAI25RE42', 'B007KGSMTS', {'time': 1452038400, 'rating': 5.0}), ('A3RTKIYFAIHFWI', 'B00YQ1NOPM', {'time': 1452038400, 'rating': 3.0}), ('A1Y1SGZB6T9RYM', 'B00VU4J8YY', {'time': 1452038400, 'rating': 5.0}), ('AIZOXW6O6NDN6', 'B00CIF0Z0K', {'time': 1452038400, 'rating': 5.0}), ('AKO4FYNQAHOC4', 'B00I08CT4Y', {'time': 1452038400, 'rating': 3.0}), ('A3OD88646VY7LE', 'B00KVSQ848', {'time': 1452038400, 'rating': 5.0}), ('A2FZB5I14T8R7M', 'B00RRCNWDQ', {'time': 1452038400, 'rating': 5.0}), ('A2XJO06SGVMH68', 'B000UVY2NK', {'time': 1452038400, 'rating': 5.0}), ('A2URF587D9YBJB', 'B0088MVPTC', {'time': 1452038400, 'rating': 5.0}), ('AKO4FYNQAHOC4', 'B00AA8WPGY', {'time': 1452038400, 'rating': 5.0}), ('A3IP9QB3D4Y11T', 'B000UQSRN6', {'time': 1452038400, 'rating': 5.0}), ('A3H2SR056XTO5Z', 'B00N4OLEN6', {'time': 1452038400, 'rating': 5.0}), ('A3FUOWM9DGBU0P', 'B00BU7WVCM', {'time': 1452038400, 'rating': 5.0}), ('A2BT79ZN6CDAL8', 'B00PMXWVE8', {'time': 1452038400, 'rating': 1.0}), ('A3JGDDXNU3LKCR', 'B007PS0938', { ...
# /tmp/ipykernel_101/168067800.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_part['line_attr'] = df_part.apply(lambda x: {'time': x['time'], 'rating':x['rating']}, axis = 1)
# EdgeView([('A14DU1XG5WW3YN', 'B0050SWP96'), ('B0050SWP96', 'A8NIZAIRT4EF7'), ('AJH7L7I3CL53U', 'B00KMRHQNA'), ('A39IZFSBWWP9H4', 'B0050SVNZ8'), ('B0050SVNZ8', 'A2P2QJXEQU5BIM'), ('B0050SVNZ8', 'A1J9G7HNVAH0D7'), ('B0050SVNZ8', 'A24HD3TRDRTNM9'), ('B0050SVNZ8', 'A27KRDZBELFVW4'), ('B0050SVNZ8', 'A3J5REDVI88HZO'), ('B0050SVNZ8', 'A2CCRGA7EVFTAC'), ('B0050SVNZ8', 'A3HL4FRUHM01A4'), ('AXOEP68E1WRBR', 'B003YL4MG0'), ('A1CPCXK1C9R6JM', 'B0012R58LG'), ('A167P2DHO7P5D7', 'B00R9NWEFK'), ('A396VHMYQHW5KE', 'B00RNDC6JU'), ('A3UTOJF5NHJI0Q', 'B00005O0I8'), ('A3B8SXBDWL1UFC', 'B00QLWZWMW'), ('A2PL7PSCA87CXN', 'B00FVVVSUY'), ('AAGT3SY5BDGOG', 'B001ELW98K'), ('A2C2F7L10X1QCI', 'B000R37S00'), ('A1ZSAWV7G5RSFW', 'B000HEB3UU'), ('A1ZSAWV7G5RSFW', 'B001V135P4'), ('A23N9PENVBQ6HC', 'B00CTOGJIW'), ('A20IBN6OIYFJQD', 'B007WQFKNC'), ('A1B7ZUQCAQB011', 'B00DNGQQUQ'), ('A2K2SRY22AEMGX', 'B001PKU5MW'), ('A3AP5XRC59REFB', 'B001B1OI0A'), ('A1XPYI1RPDQLNZ', 'B0097TM6AC'), ('A2JEFXZATFYV3K', 'B006ZUNKL0'), ('A2Y1INHBJOQY0D', 'B00AAS888S'), ('B00AAS888S', 'A10C8OK74VKFYG'), ('B00AAS888S', 'A10PO803811GVF'), ('B00AAS888S', 'A2UTQBD31N4DMD'), ('A1H1U67JFF7N7T', 'B0098R0600'), ('B0098R0600', 'AWUSWLZ05HIR8'), ('B0098R0600', 'A332OBC88IUVPF'), ('B0098R0600', 'A3CR2GR7BNZI0G'), ('A3MMM8X8W07O19', 'B000FFA08C'), ('AZF6PHVCUN8GI', 'B00550EIDA'), ('AFBCOD46GIFQ7', 'B000WZL5GQ'), ('A30EBZKII2V5VX', 'B00W76UJBK'), ('ABRJBPP4ZBMW1', 'B016BBM6FI'), ('A11PK2MO25K5QW', 'B00201EFK8'), ('A1NHAL9A6RWQ62', 'B00005NOFH'), ('A7HKGNXQD7LVP', 'B00M0Z04C2'), ('A11G2YC3X2KFJB', 'B00CBNVAE4'), ('A2O822D7AOKDOG', 'B00HEAS7JA'), ('A2E2TIXKHWDKZZ', 'B00DHOBFDW'), ('A2E2TIXKHWDKZZ', 'B004VQENY8'), ('A3TVY6OQF9R11A', 'B00DEE7F7K'), ('A3UG1SIKT89BO6', 'B0079GHJXY'), ('B0079GHJXY', 'A37BKAD30OOL1Z'), ('B0079GHJXY', 'A15H87XBHZZ9XS'), ('B0079GHJXY', 'A26CUPOVOGSH2Q'), ('A2AD38PUZ3C4HD', 'B002E41PVS'), ('A3G4346778UN92', 'B00FLLFJOU'), ('A27I9VC2SP5VDN', 'B00MUY0OFU'), ('A1B6ZHDSQZBEQX', 'B007XUQXL0'), ('A3TX4F65UWRO5X', 'B000HCLLNG'), ('A20ROZAI25RE42', 'B007KGSMTS'), ('A3RTKIYFAIHFWI', 'B00YQ1NOPM'), ('B00YQ1NOPM', 'A2LJFBPNTI0WFR'), ('B00YQ1NOPM', 'A3UBSED45B09PS'), ('B00YQ1NOPM', 'A1WVGB7T5KB2L8'), ('B00YQ1NOPM', 'A1UFJJHSTR4ZUB'), ('A1Y1SGZB6T9RYM', 'B00VU4J8YY'), ('B00VU4J8YY', 'A34HELBQZVS8AB'), ('AIZOXW6O6NDN6', 'B00CIF0Z0K'), ('B00CIF0Z0K', 'A24U81C252UZ5C'), ('B00CIF0Z0K', 'A3LGT6UZL99IW1'), ('AKO4FYNQAHOC4', 'B00I08CT4Y'), ('AKO4FYNQAHOC4', 'B00AA8WPGY'), ('A3OD88646VY7LE', 'B00KVSQ848'), ('B00KVSQ848', 'A1U6764MPB3HOF'), ('B00KVSQ848', 'AF8S6ZDPNZWCR'), ('B00KVSQ848', 'A2ATGYGLVFGBRC'), ('B00KVSQ848', 'ASQX2E5QWIN0C'), ('A2FZB5I14T8R7M', 'B00RRCNWDQ'), ('A2FZB5I14T8R7M', 'B001LUJX38'), ('A2XJO06SGVMH68', 'B000UVY2NK'), ('A2URF587D9YBJB', 'B0088MVPTC'), ('B00AA8WPGY', 'A3HR1YY1ZAXXZM'), ('A3IP9QB3D4Y11T', 'B000UQSRN6'), ('A3H2SR056XTO5Z', 'B00N4OLEN6'), ('A3FUOWM9DGBU0P', 'B00BU7WVCM'), ('A2BT79ZN6CDAL8', 'B00PMXWVE8'), ('A3JGDDXNU3LKCR', 'B007PS0938'), ('A27TVBD5GVDHD8', 'B007AQZAW0'), ('A34Q65PNVVTDEL', 'B0039ZFL98'), ('A1LPUZN5NLJT1R', 'B000ET6RUO'), ('A2OXRXUVPXRC9H', 'B000W16JAC'), ('A1R4YYGO9C92F5', 'B005T5OCAK'), ('A1I68CFWFZ7L1O', 'B00AAV70XY'), ('A2WVG0RN9F7FCM', 'B001JFTDLM'), ('A27OD0HADYKZM0', 'B00HVPFGD8'), ('A32ZK9IRSEY61T', 'B0000A92KX'), ('AMM4TU12QXO1A', 'B0010EI6T2'), ('A1D4O9JOOP7S3C', 'B0050SYOOA'), ('A1ULN8W27KHKJU', 'B000NWYPD8'), ('A1ULN8W27KHKJU', 'B000930DLO'), ('AG31E3Y1CM9RY', 'B001NCDAV0'), ('ARKLONYP75BR3', 'B0000A30R8'), ('AIIZ951OZZ6I9', 'B00BGAA3S2'), ('B00BGAA3S2', 'A1QS4UMRMR0SSE'), ('B00BGAA3S2', 'A1X9HXCA223V94'), ('B00BGAA3S2', 'A2RDDCIXDL95PX'), ('AW9TN9DNDROZK', 'B00BGA9Y3W'), ('B00BGA9Y3W', 'A3MQ5EEQQCKURM'), ('B00BGA9Y3W', 'A1M8XMEB9DQCSR'), ('A1JDXBW3ALMW7Z', 'B00X87BLK0'), ('B00X87BLK0', 'A15Y6X8FDV62P6'), ('B00X87BLK0', 'A1WIHLF5VUKY5C'), ('A36M3TLWKODL2N', 'B00CMSCT8Y'), ('A3SSTT6VFBDTAD', 'B00T0K8LL6'), ('A1Z592LI0QPIMN', 'B003KZJA9Y'), ('A2TQIU6YLFBBNI', 'B000VVEMXY'), ('A3JH61E1E5AXQ', 'B00NCA8QUG'), ('A2H7VZFABQDWEF', 'B0007V46IY') ...

# %%
len(s.model.edges())
# Out:
# 9489

# %%
s.model['A3N9FDER4SGFQU']
# Out:
# AtlasView({'B00HVMFAPK': {'time': 1451692800, 'rating': 5.0}})

# %%
s.model['A3N9FDER4SGFQU']['B00HVMFAPK']
# Out:
# {'time': 1451692800, 'rating': 5.0}

# %%
#s.model.nodes(data = True)

# %%
s.model['B0068AD39Q']
# Out:
# AtlasView({'A396VHMYQHW5KE': {'time': 1451692800, 'rating': 5.0}})

# %%
#s.draw(fig_size = (20,100), width = 0.03, save = True)

# %%
np.random.normal(5 * 2,2,1)
# Out:
# array([12.34223067])

# %%
a = df[['user','asin']]
a.itertuples(index=False, name=None)

# %%
B = nx.Graph()
# Add nodes with the node attribute "bipartite"
B.add_nodes_from(set(df['user']), bipartite=0)
B.add_nodes_from(set(df['asin']), bipartite=1)
# Add edges only between nodes of opposite node sets
B.add_weighted_edges_from(df[['user','asin', 'rating']].itertuples(index=False, name=None))
nx.set_node_attributes(B, 0, "grain")

# %%
#B.degree()
